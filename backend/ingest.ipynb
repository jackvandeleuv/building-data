# %%
import requests

data = []

offset = 0
while True:
    print(offset)
    base = (
        'https://services3.arcgis.com/dty2kHktVXHrqO8i/arcgis/rest/services/Complaint_Status_History/FeatureServer/0/query'
        '?outFields=*'
        f'&resultOffset={offset}'
        '&where=1=1'
        '&f=json'
    )

    response = requests.get(base)
    response.raise_for_status()

    features = response.json()['features']

    if not features:
        break

    attributes = [row.get('attributes', {}) for row in features]
    offset += len(attributes)

    data = data + attributes
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# ...

# %%
data[995 : 1005]
# Out:
# [{'ObjectId': 996,
#   'PERMIT_ID': 'CMP25019152',
#   'FILE_DATE': 1749528000000,
#   'SOURCE': 'Public',
#   'CURRENT_TASK': 'Closure',
#   'CURRENT_TASK_STATUS': 'Closed-Valid Violation',
#   'TASK_DATE': 1750132800000,
#   'PRIMARY_ADDRESS': '7712 ELTON AVE, CLEVELAND, OH, 44102',
#   'PARCEL_NUMBER': '00604151',
#   'TYPE_OF_COMPLAINT': 'O.V.V.',
#   'ACCELA_CITIZEN_ACCESS_URL': 'https://aca-prod.accela.com/COC/Cap/CapDetail.aspx?Module=BuildingHousing&TabName=BuildingHousing&capID1=25BCE&capID2=00000&capID3=11150&agencyCode=COC&IsToShowInspection=',
#   'DW_Parcel': '00604151',
#   'DW_Ward': '15.0',
#   'DW_Ward2026': 11,
#   'DW_Ward2014': 15,
#   'DW_Tract2020': '39035101800',
#   'DW_Neighborhood': 'Detroit Shoreway'},
#  {'ObjectId': 997,
#   'PERMIT_ID': 'CMP25019171',
#   'FILE_DATE': 1749528000000,
#   'SOURCE': 'Public',
#   'CURRENT_TASK': 'Complaint Acceptance',
#   'CURRENT_TASK_STATUS': 'Routine Complaint Received',
#   'TASK_DATE': 1749528000000,
# ...

# %%
r.json()['features']
# Out:
# []
